# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('/content/house price.xlsx')
print(df)
# Out:
#    house price in $1000  square feet(x)
# 0                   245            1400
# 1                   312            1600
# 2                   279            1790
# 3                   308            1875
# 4                   199            1100
# 5                   219            1550
# 6                   405            2350
# 7                   324            2450
# 8                   319            1425
# 9                   255            1700

# %%
df.isnull().sum()
# Out:
# house price in $1000    0
# square feet(x)          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['house price in $1000', 'square feet(x)'], dtype='object')

# %%
plt.scatter(df['square feet(x)'],df['house price in $1000'])
plt.xlabel('square feet')
plt.ylabel('house price')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

X = df[["square feet(x)"]]
y = df[["house price in $1000"]]

model = LinearRegression()
model.fit(X, y)

print("Model coefficients:", model.coef_)
print("Model intercept:", model.intercept_)

y_pred = model.predict(X)

plt.scatter(X, y)
plt.plot(X, y_pred, color="red")
plt.show()
# Out:
# Model coefficients: [[0.10901979]]
# Model intercept: [98.54988294]

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
print('R square',r2_score(y,y_pred)*100)
# Out:
# R square 57.46023934367219

# %%
print('mean_absolute_error',mean_absolute_error(y,y_pred)*100)
# Out:
# mean_absolute_error 3188.139890488487

# %%
print('mean_squared_error',mean_squared_error(y,y_pred)*100)
# Out:
# mean_squared_error 138681.74672766146

# %%
import statsmodels.api as sm
result = sm.OLS(y, x).fit()

# printing the summary table
print(result.summary())
# Out:
#                                   OLS Regression Results
# ...
# Dep. Variable:     house price in $1000   R-squared (uncentered):                   0.978
# Model:                              OLS   Adj. R-squared (uncentered):              0.976
# Method:                   Least Squares   F-statistic:                              400.4
# Date:                  Tue, 19 Mar 2024   Prob (F-statistic):                    9.03e-09
# Time:                          03:56:04   Log-Likelihood:                         -51.874
# No. Observations:                    10   AIC:                                      105.7
# Df Residuals:                         9   BIC:                                      106.0
# Df Model:                             1
# Covariance Type:              nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...
